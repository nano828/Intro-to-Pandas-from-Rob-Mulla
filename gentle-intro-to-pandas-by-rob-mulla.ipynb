# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
mydata = ['Boat', 'Car', 'Bike', 'Truck']

myseries = pd.Series(mydata)

print(myseries)
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# dtype: object

# %% [markdown]
# # DataFrame

# %%
mydfdata = [('Adnan', 'Nahlawi', 33), ('Sharief', 'Oteafy', 12), ('Faysal', 'Naamani', 23), ('Laiyan', 'Bawadeen', 54)]

mydf = pd.DataFrame(mydfdata, columns=['First', 'Last', 'Number'])

print(mydf)

mydf
# Out:
#      First      Last  Number
# 0    Adnan   Nahlawi      33
# 1  Sharief    Oteafy      12
# 2   Faysal   Naamani      23
# 3   Laiyan  Bawadeen      54
#      First      Last  Number
# 0    Adnan   Nahlawi      33
# 1  Sharief    Oteafy      12
# 2   Faysal   Naamani      23
# 3   Laiyan  Bawadeen      54

# %% [markdown]
# # Columns

# %%
mydf['First']
# Out:
# 0      Adnan
# 1    Sharief
# 2     Faysal
# 3     Laiyan
# Name: First, dtype: object

# %%
mydf['Last']
# Out:
# 0     Nahlawi
# 1      Oteafy
# 2     Naamani
# 3    Bawadeen
# Name: Last, dtype: object

# %%
mydf['Number']
# Out:
# 0    33
# 1    12
# 2    23
# 3    54
# Name: Number, dtype: int64

# %% [markdown]
# # Rows

# %%
mydf.loc[1]
# Out:
# First     Sharief
# Last       Oteafy
# Number         12
# Name: 1, dtype: object

# %%
mydf.loc[0]
# Out:
# First       Adnan
# Last      Nahlawi
# Number         33
# Name: 0, dtype: object

# %%
mydf.dtypes
# Out:
# First     object
# Last      object
# Number     int64
# dtype: object

# %%
df = pd.read_csv('../input/university-employee-salaries-2011-present/higher_ed_employee_salaries.csv')

# %%
df.shape
# Out:
# (934348, 6)

# %%
df.head(20)
# Out:
#                     Name                          School  \
# 0             Don Potter             University of Akron
# 1           Emily Potter       The Ohio State University
# 2      Carol Jean Potter       The Ohio State University
# 3             Kim Potter       The Ohio State University
# 4          Graham Potter                Miami University
# 5          Amanda Potter       The Ohio State University
# 6     Susan Marie Potter       The Ohio State University
# 7         Katrina Potter                Miami University
# 8     Pamela Lynn Potter  Bowling Green State University
# 9      Kimberly J Potter       The Ohio State University
# 10           Adam Potter       The Ohio State University
# 11          Maria Potter        Central State University
# 12          Scott Potter       The Ohio State University
# 13         Ryan M Potter       The Ohio State University
# 14         Archie Potter                 Ohio University
# ...

# %%
df.tail(3)
# Out:
#                         Name                          School  \
# 934345  Kristen Lindsay Noon       The Ohio State University
# 934346         Danielle Noon            University of Toledo
# 934347          Kevin R Noon  Bowling Green State University
#
#                      Job Description            Department   Earnings  Year
# 934345  Assistant Professor-Clinical        Anesthesiology  243033.56  2018
# 934346             Medical Assistant  OP-Clinic-Orthopedic   37642.16  2022
# 934347    Asst Men's Basketbal Coach      Basketball - Men  103630.58  2022

# %%
df.dtypes
# Out:
# Name                object
# School              object
# Job Description     object
# Department          object
# Earnings           float64
# Year                 int64
# dtype: object

# %%
df.describe()
# Out:
#            Earnings           Year
# count  9.246730e+05  934348.000000
# mean   5.465913e+04    2017.102828
# std    6.137398e+04       3.183910
# min    2.000000e-02    2011.000000
# 25%    2.024923e+04    2014.000000
# 50%    4.452501e+04    2017.000000
# 75%    7.099997e+04    2020.000000
# max    8.021377e+06    2022.000000

# %% [markdown]
# # Columns and Rows

# %%
df['School']
# Out:
# 0                    University of Akron
# 1              The Ohio State University
# 2              The Ohio State University
# 3              The Ohio State University
# 4                       Miami University
#                        ...
# 934343              University of Toledo
# 934344              University of Toledo
# 934345         The Ohio State University
# 934346              University of Toledo
# 934347    Bowling Green State University
# Name: School, Length: 934348, dtype: object

# %%
df.loc[4]
# Out:
# Name                                     Graham Potter
# School                                Miami University
# Job Description         Building and Grounds Assistant
# Department         Assoc VP Housing,Dining,Rec,Bus Svc
# Earnings                                        3075.2
# Year                                              2012
# Name: 4, dtype: object

# %%
df2 = df.set_index('Name')

# %%
df2.loc['Kim Potter']
# Out:
#                                School        Job Description  \
# Name
# Kim Potter  The Ohio State University  Manager 4, Compliance
# Kim Potter  The Ohio State University            Director-00
# Kim Potter  The Ohio State University            Director-00
# Kim Potter  The Ohio State University            Director-00
#
#                             Department   Earnings  Year
# Name
# Kim Potter  Legal Affairs | Compliance  170143.44  2022
# Kim Potter                  University  125232.25  2021
# Kim Potter                  University  125232.25  2021
# Kim Potter                  University  125232.25  2021

# %% [markdown]
# # Subsetting Columns

# %%
df.columns
# Out:
# Index(['Name', 'School', 'Job Description', 'Department', 'Earnings', 'Year'], dtype='object')

# %%
# Subsetting columns
df[['Name', 'Earnings']]
# Out:
#                         Name   Earnings
# 0                 Don Potter    2472.00
# 1               Emily Potter   48538.02
# 2          Carol Jean Potter   22722.80
# 3                 Kim Potter  170143.44
# 4              Graham Potter    3075.20
# ...                      ...        ...
# 934343         Danielle Noon   31659.43
# 934344         Danielle Noon    7974.25
# 934345  Kristen Lindsay Noon  243033.56
# 934346         Danielle Noon   37642.16
# 934347          Kevin R Noon  103630.58
#
# [934348 rows x 2 columns]

# %%
# Subsetting rows using loc
df['Year']== 2012
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 934343    False
# 934344    False
# 934345    False
# 934346    False
# 934347    False
# Name: Year, Length: 934348, dtype: bool

# %%
df.loc[df['Year']== 2012]
# Out:
#                         Name                          School  \
# 4              Graham Potter                Miami University
# 7             Katrina Potter                Miami University
# 8         Pamela Lynn Potter  Bowling Green State University
# 90           Jennifer Potter                 Ohio University
# 112           Lee Poeppelman        University Of Cincinnati
# ...                      ...                             ...
# 934245  William Lewis Schurk  Bowling Green State University
# 934255     Stephanie Nolting        University Of Cincinnati
# 934271         Kei Nomaguchi  Bowling Green State University
# 934302    Susanne Nonekowski            University of Toledo
# 934326          Suba Nookala        University Of Cincinnati
#
#                        Job Description                           Department  \
# 4       Building and Grounds Assistant  Assoc VP Housing,Dining,Rec,Bus Svc
# 7                 Personnel Technician            VP for Acad Affrs-Provost
# ...

# %%
#df = df.drop('year', axis=1)

# %%
df
# Out:
#                         Name                          School  \
# 0                 Don Potter             University of Akron
# 1               Emily Potter       The Ohio State University
# 2          Carol Jean Potter       The Ohio State University
# 3                 Kim Potter       The Ohio State University
# 4              Graham Potter                Miami University
# ...                      ...                             ...
# 934343         Danielle Noon            University of Toledo
# 934344         Danielle Noon            University of Toledo
# 934345  Kristen Lindsay Noon       The Ohio State University
# 934346         Danielle Noon            University of Toledo
# 934347          Kevin R Noon  Bowling Green State University
#
#                        Job Description  \
# 0                   Assistant Lecturer
# 1           Administrative Assistant 3
# 2         Associate Professor-Clinical
# 3                Manager 4, Compliance
# ...

# %%
# Subsetting rows using query
df.query('Year==2011')
# Out:
#                              Name                      School  \
# 55              Crystal M. Potter    University Of Cincinnati
# 200              Cynthia Scherzer        University of Toledo
# 219         Jacquelyn M. Schetter     Wright State University
# 242             Joanne Scheuerman        University of Toledo
# 247     William Barry Scheuermann        University of Toledo
# ...                           ...                         ...
# 934222            Shannon M Schur  Cleveland State University
# 934241        Jennifer D Schurdak    University Of Cincinnati
# 934258          Stephanie Nolting    University Of Cincinnati
# 934308         Susanne Nonekowski        University of Toledo
# 934325               Suba Nookala    University Of Cincinnati
#
#               Job Description                     Department   Earnings  Year
# 55         Research Assistant     COM IM Immunology Division   31221.01  2011
# ...

# %% [markdown]
# # Dropping NAN Earnings

# %%
df = df.loc[~df['Earnings'].isna()].copy()

# %% [markdown]
# # Converting Column to integer

# %%
df['Earnings'] = df['Earnings'].astype('int')

# %%
df
# Out:
#                         Name                          School  \
# 0                 Don Potter             University of Akron
# 1               Emily Potter       The Ohio State University
# 2          Carol Jean Potter       The Ohio State University
# 3                 Kim Potter       The Ohio State University
# 4              Graham Potter                Miami University
# ...                      ...                             ...
# 934343         Danielle Noon            University of Toledo
# 934344         Danielle Noon            University of Toledo
# 934345  Kristen Lindsay Noon       The Ohio State University
# 934346         Danielle Noon            University of Toledo
# 934347          Kevin R Noon  Bowling Green State University
#
#                        Job Description  \
# 0                   Assistant Lecturer
# 1           Administrative Assistant 3
# 2         Associate Professor-Clinical
# 3                Manager 4, Compliance
# ...

# %%
df.dtypes
# Out:
# Name               object
# School             object
# Job Description    object
# Department         object
# Earnings            int64
# Year                int64
# dtype: object

# %% [markdown]
# # Adding Column

# %%
df['High_Salary'] = df['Earnings']>130_000

# %%
df
# Out:
#                         Name                          School  \
# 0                 Don Potter             University of Akron
# 1               Emily Potter       The Ohio State University
# 2          Carol Jean Potter       The Ohio State University
# 3                 Kim Potter       The Ohio State University
# 4              Graham Potter                Miami University
# ...                      ...                             ...
# 934343         Danielle Noon            University of Toledo
# 934344         Danielle Noon            University of Toledo
# 934345  Kristen Lindsay Noon       The Ohio State University
# 934346         Danielle Noon            University of Toledo
# 934347          Kevin R Noon  Bowling Green State University
#
#                        Job Description  \
# 0                   Assistant Lecturer
# 1           Administrative Assistant 3
# 2         Associate Professor-Clinical
# 3                Manager 4, Compliance
# ...

# %% [markdown]
# # Adding row

# %%
df_last_row = df.tail(1)

# %%
pd.concat([df,df_last_row])
# Out:
#                         Name                          School  \
# 0                 Don Potter             University of Akron
# 1               Emily Potter       The Ohio State University
# 2          Carol Jean Potter       The Ohio State University
# 3                 Kim Potter       The Ohio State University
# 4              Graham Potter                Miami University
# ...                      ...                             ...
# 934344         Danielle Noon            University of Toledo
# 934345  Kristen Lindsay Noon       The Ohio State University
# 934346         Danielle Noon            University of Toledo
# 934347          Kevin R Noon  Bowling Green State University
# 934347          Kevin R Noon  Bowling Green State University
#
#                        Job Description  \
# 0                   Assistant Lecturer
# 1           Administrative Assistant 3
# 2         Associate Professor-Clinical
# 3                Manager 4, Compliance
# ...

# %%
import matplotlib.pylab as plt
plt.style.use('ggplot')

# %%
df['Earnings'].plot(kind='hist', bins=1000, title='Distribution of Salaries', figsize=(15, 5), xlim=(0,2000_000), )
# Out:
# <Axes: title={'center': 'Distribution of Salaries'}, ylabel='Frequency'>

# %%
df.plot(kind='scatter', x='Year', y='Earnings')
# Out:
# <Axes: xlabel='Year', ylabel='Earnings'>

# %%
df = df.query('Earnings<350_000')

# %%
df['Earnings'].plot(kind='hist', bins=100, title='Distribution of Salaries', figsize=(15, 5) )
# Out:
# <Axes: title={'center': 'Distribution of Salaries'}, ylabel='Frequency'>

# %% [markdown]
# # Saving Output

# %%
df.to_csv('Processed_data_AIN.csv', index=False)
